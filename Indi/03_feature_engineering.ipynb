# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import *

# %%
df = pd.read_csv('sell_in_filtrado_con_tn.csv', sep='\t')
df.shape
# Out:
# (7781619, 6)

# %%
df.head()
# Out:
#     period  product_id  customer_id         tn cat1     target
# 0  2017-01       20001        10001   99.43861   HC   92.46537
# 1  2017-02       20001        10001  198.84365   HC   13.29728
# 2  2017-03       20001        10001   92.46537   HC  101.00563
# 3  2017-04       20001        10001   13.29728   HC  128.04792
# 4  2017-05       20001        10001  101.00563   HC  101.20711

# %%
# 1) Extraer el mapeo único product_id → cat1 usando solo filas donde cat1 NO sea NaN
df_prod_cat1 = (
    df[['product_id','cat1']]
    .dropna(subset=['cat1'])                # descartamos filas donde cat1 es NaN
    .drop_duplicates(subset=['product_id'])  # nos quedamos con la primera ocurrencia por product_id
    .reset_index(drop=True)
)

# Verificamos si, para algún product_id, hay más de un cat1 distinto (inconsistencias)
inconsistencias = (
    df[['product_id','cat1']]
    .dropna(subset=['cat1'])
    .drop_duplicates()
    .groupby('product_id')['cat1']
    .nunique()
    .loc[lambda s: s > 1]
)
if len(inconsistencias) > 0:
    print("Estos product_id tienen más de una categoría cat1 registrada:")
    print(inconsistencias)
else:
    print("Todos los product_id tienen una sola cat1 consistente (ignorando NaN).")

# Ahora df_prod_cat1 tiene dos columnas: ['product_id','cat1'], con un único cat1 por producto.
print("\nDataFrame product_id → cat1 (sin NaN):")
print(df_prod_cat1.head())
# Out:
# Todos los product_id tienen una sola cat1 consistente (ignorando NaN).
#
# DataFrame product_id → cat1 (sin NaN):
#    product_id   cat1
# 0       20001     HC
# 1       20002     HC
# 2       20003  FOODS
# 3       20004  FOODS
# 4       20005  FOODS

# %%
# 2) Convertir este mapeo en un diccionario para hacer un .map() más adelante
mapeo_cat1 = dict(zip(df_prod_cat1['product_id'], df_prod_cat1['cat1']))

# 3) Rellenar los NaN de df['cat1'] usando ese mapeo
#    Solo afectará a filas donde df['cat1'] es NaN pero product_id existe en mapeo_cat1
df['cat1'] = df['cat1'].fillna(df['product_id'].map(mapeo_cat1))

# 4) (Opcional) Verificar cuántos NaN quedaron en cat1 tras rellenar
nan_restantes = df['cat1'].isna().sum()
print(f"\nCantidad de filas que todavía tienen cat1 = NaN: {nan_restantes}")
# Out:
# Cantidad de filas que todavía tienen cat1 = NaN: 0

# %% [markdown]
# ###  Variables de calendario / estacionales

# %%
df['periodo'] = df['period']

# %%
# Convertir 'periodo' a PeriodIndex mensual
df['period'] = pd.to_datetime(df['period'], format='%Y-%m').dt.to_period('M')

# Extraer mes y año como features numéricas
df['year']  = df['period'].dt.year
df['month'] = df['period'].dt.month
df['days_in_month'] = df['period'].dt.days_in_month
df['semester'] = ((df['month'] - 1) // 6) + 1
df['quarter'] = df['period'].dt.quarter
df['month_q'] = ((df['period'].dt.month - 1) % 3) + 1

# Orden secuencial global
first_period = df['period'].min()
df['period_ordinal'] = ((df['year'] - first_period.year) * 12) + (df['month'] - first_period.month + 1)

# %%
# Continuidad temporal (cíclica) usando seno y coseno
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

df['quarter_sin'] = np.sin(2 * np.pi * df['quarter'] / 4)
df['quarter_cos'] = np.cos(2 * np.pi * df['quarter'] / 4)

# Estacionalidad global 
N = df['period_ordinal'].max()  # O ponés 36 si es fijo
df['period_ordinal_sin'] = np.sin(2 * np.pi * df['period_ordinal'] / N)
df['period_ordinal_cos'] = np.cos(2 * np.pi * df['period_ordinal'] / N)

# %%
# Indicar “temporada alta”/“temporada baja” (ejemplo generalista)
df['is_summer'] = df['month'].isin([12, 1, 2]).astype(int)
df['is_winter'] = df['month'].isin([6, 7, 8]).astype(int)

# 3.4. Indicador de “pre-campaña” (suponiendo picos en marzo y octubre)
df['pre_march']   = (df['month'] == 2).astype(int)
df['pre_october'] = (df['month'] == 9).astype(int)

# %% [markdown]
# ### OneHotEncoder Cat1

# %%
from sklearn.preprocessing import OneHotEncoder

# Defino el encoder
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# Ajusto y transformo
cat1_ohe = ohe.fit_transform(df[['cat1']])

# Defino el nombre “cat1_HC”, “cat1_FC”, etc.
ohe_cols = ohe.get_feature_names_out(['cat1'])

# Creo un DataFrame con los nombres de las columnas
cat1_df = pd.DataFrame(cat1_ohe, columns=ohe_cols, index=df.index)

# Uno al DataFrame original
df = pd.concat([df, cat1_df], axis=1)

# %%
df['cat1'].value_counts(dropna=False)
# Out:
# cat1
# PC       4398482
# HC       1952471
# FOODS    1389007
# REF        41659
# Name: count, dtype: int64

# %%
df.drop(columns=['cat1'], inplace=True)

# %% [markdown]
# ### Lags y rolling-windows sobre tn
# #### Lags simples

# %%
# Asegurarnos de que df_full esté ordenado correctamente
df = df.sort_values(['product_id','customer_id','period'])

# Lags 1 a 36
for lag in range(1, 37):
    df[f'tn_lag{lag}'] = (
        df
        .groupby(['product_id', 'customer_id'])['tn']
        .shift(lag)
    )

# %% [markdown]
# #### Rolling-mean y rolling-std (ventanas móviles)

# %%
for window in range(2, 37):
    # Media móvil
    df[f'tn_roll{window}'] = (
        df
        .groupby(['product_id', 'customer_id'])['tn']
        .rolling(window=window, min_periods=1)
        .mean()
        .reset_index(level=[0,1], drop=True)
    )
    # Desvío estándar móvil
    df[f'tn_rollstd{window}'] = (
        df
        .groupby(['product_id', 'customer_id'])['tn']
        .rolling(window=window, min_periods=1)
        .std()
        .reset_index(level=[0,1], drop=True)
    )
    # Mínimo móvil
    df[f'tn_rollmin{window}'] = (
        df
        .groupby(['product_id', 'customer_id'])['tn']
        .rolling(window=window, min_periods=1)
        .min()
        .reset_index(level=[0,1], drop=True)
    )
    # Máximo móvil
    df[f'tn_rollmax{window}'] = (
        df
        .groupby(['product_id', 'customer_id'])['tn']
        .rolling(window=window, min_periods=1)
        .max()
        .reset_index(level=[0,1], drop=True)
    )
# Out:
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_roll{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollstd{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmin{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3323808436.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rollmax{window}'] = (

# %%
# Indicador binario de nuevo maximo y nuevo minimo
for window in range(2, 37):
    # Nuevo máximo en la ventana: 1 si el valor actual es igual al máximo móvil
    df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
    
    # Nuevo mínimo en la ventana: 1 si el valor actual es igual al mínimo móvil
    df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# Out:
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmax{window}'] = (df['tn'] == df[f'tn_rollmax{window}']).astype(int)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3436198303.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_is_new_rollmin{window}'] = (df['tn'] == df[f'tn_rollmin{window}']).astype(int)

# %% [markdown]
# ### Ratio entre el valor actual y el promedio móvil

# %%
for window in range(2, 37):
    df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# Out:
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/261284901.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_div_roll{window}'] = df['tn'] / (df[f'tn_roll{window}'] + 1e-6)

# %% [markdown]
# ### Delta lags

# %%
# for lag in range(1, 37):  # Por ejemplo, los últimos 12 meses
#     df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']

# # Segunda diferenciacion (delta del delta)
# for lag in range(2, 13):
#     df[f'tn_accel{lag}'] = df[f'tn_delta{lag-1}'] - df[f'tn_delta{lag}']

# # Ratios del delta
# for lag in range(1, 13):
#     df[f'tn_rel_delta{lag}'] = df['tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)

# %%
# Primer paso: calcular los delta y delta relativos
for lag in range(1, 13):
    df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
    df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)

# Segundo paso: calcular los delta del delta
for lag in range(1, 12):  # Hasta 11 porque el 12 no tiene siguiente
    df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# Out:
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_delta{lag}'] = df['tn'] - df[f'tn_lag{lag}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_rel_delta{lag}'] = df[f'tn_delta{lag}'] / (df[f'tn_lag{lag}'] + 1e-6)
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3407017344.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_accel{lag}'] = df[f'tn_delta{lag}'] - df[f'tn_delta{lag+1}']

# %% [markdown]
# ### Tendencia

# %%
def rolling_slope(x, window):
    idx = np.arange(window)
    def _slope(arr):
        if len(arr) < window:
            arr = arr[-window:]
            idx2 = np.arange(len(arr))
            if len(arr) < 2:
                return np.nan
            return np.polyfit(idx2, arr, 1)[0]
        return np.polyfit(idx, arr, 1)[0]
    return x.rolling(window).apply(_slope, raw=True)

for window in [2, 3, 6, 9, 12, 18, 24, 36]:
    df[f'tn_trend_slope{window}'] = (
        df
        .groupby(['product_id','customer_id'])['tn']
        .apply(lambda x: rolling_slope(x, window))
        .reset_index(level=[0,1], drop=True)
    )
# Out:
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/3768242003.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'tn_trend_slope{window}'] = (

# %%
df['tn_vs_ma12'] = df['tn'] - df['tn_roll12']
# Out:
# /var/folders/c5/g8wp4j8j1nd226rj0lw9_vz40000gn/T/ipykernel_34795/2049547643.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['tn_vs_ma12'] = df['tn'] - df['tn_roll12']

# %% [markdown]
# ### Edad del producto y del cliente (feature “edad”)

# %%
# Primer periodo (nacimiento) de cada producto y cada cliente
prod_nac = (
    df
    .groupby('product_id')['period']
    .min()
    .reset_index()
    .rename(columns={'period': 'prod_start'})
)

cust_nac = (
    df
    .groupby('customer_id')['period']
    .min()
    .reset_index()
    .rename(columns={'period': 'cust_start'})
)

# %%
# Suponiendo que ya tienes prod_nac y cust_nac
# Unir a df_full las fechas de nacimiento
df = df.merge(prod_nac, on='product_id', how='left')
df = df.merge(cust_nac, on='customer_id', how='left')

# Edad en meses de product_id en cada fila
df['prod_age'] = (df['period'] - df['prod_start']).apply(lambda x: x.n)

# Edad en meses de customer_id en cada fila
df['cust_age'] = (df['period'] - df['cust_start']).apply(lambda x: x.n)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Indicadores de “actividad” / “inactividad prolongada”

# %%
# Función que calcula la racha de meses consecutivos sin vender
def calcular_racha_no_ventas(serie_no_sale: pd.Series) -> pd.Series:
    """
    Dada una Serie booleana/0-1 que indica para cada mes si no hubo venta (1) o sí hubo (0),
    devuelve otra Serie del mismo tamaño donde cada posición es el número de meses consecutivos
    sin venta que lleva hasta esa fila (incluyéndola). Reinicia a 0 cuando hay venta.
    """
    racha = []
    cuenta = 0
    for valor in serie_no_sale:
        if valor == 1:
            cuenta += 1
        else:
            cuenta = 0
        racha.append(cuenta)
    return pd.Series(racha, index=serie_no_sale.index)

df = df.sort_values(['product_id','customer_id','period']).copy()

# Calcular no_sale (1 si tn == 0, ó 0 si tn > 0)
df['no_sale'] = (df['tn'] == 0).astype(int)

# 4) Aplicar la función por cada grupo <product_id, customer_id>
df['no_sale_streak'] = (
    df
    .groupby(['product_id','customer_id'])['no_sale']
    .apply(calcular_racha_no_ventas)
    .reset_index(level=[0,1], drop=True)
)

# %%
# 5) Verificar manualmente un ejemplo para confirmar que ahora sí reinicia
print(df.loc[
    (df['product_id']==21266) & (df['customer_id']==10040),
    ['period','tn','no_sale','no_sale_streak']
])
# Out:
#           period       tn  no_sale  no_sale_streak
# 7780615  2019-03  0.00000        1               1
# 7780616  2019-04  0.05801        0               0
# 7780617  2019-05  0.00000        1               1
# 7780618  2019-06  0.01479        0               0
# 7780619  2019-07  0.00000        1               1
# 7780620  2019-08  0.00114        0               0
# 7780621  2019-09  0.00000        1               1
# 7780622  2019-10  0.00000        1               2
# 7780623  2019-11  0.00000        1               3
# 7780624  2019-12  0.00000        1               4

# %%
df.head()
# Out:
#     period  product_id  customer_id         tn     target  cat1_FOODS  \
# 0  2017-01       20001        10001   99.43861   92.46537         0.0
# 1  2017-02       20001        10001  198.84365   13.29728         0.0
# 2  2017-03       20001        10001   92.46537  101.00563         0.0
# 3  2017-04       20001        10001   13.29728  128.04792         0.0
# 4  2017-05       20001        10001  101.00563  101.20711         0.0
#
#    cat1_HC  cat1_PC  cat1_REF    tn_lag1  ...  share_cliente  prod_start  \
# 0      1.0      0.0       0.0        NaN  ...       0.052969     2017-01
# 1      1.0      0.0       0.0   99.43861  ...       0.085162     2017-01
# 2      1.0      0.0       0.0  198.84365  ...       0.032619     2017-01
# 3      1.0      0.0       0.0   92.46537  ...       0.005350     2017-01
# 4      1.0      0.0       0.0   13.29728  ...       0.036501     2017-01
#
#    cust_start  prod_age  cust_age  no_sale  no_sale_streak  tn_slope3  \
# 0     2017-01         0         0        0               0        NaN
# 1     2017-01         1         1        0               0  99.405040
# 2     2017-01         2         2        0               0  -3.486620
# 3     2017-01         3         3        0               0 -92.773185
# 4     2017-01         4         4        0               0   4.270130
#
#    tn_slope6  tn_slope12
# 0        NaN         NaN
# 1  99.405040   99.405040
# 2  -3.486620   -3.486620
# 3 -36.480227  -36.480227
# 4 -18.241233  -18.241233
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Validamos posibles inf o NaN

# %%
# Lista para acumular resultados
resultados = []

for col in df.columns:
    nulos = df[col].isnull().sum()
    # Solo contamos infinitos si la columna es numérica
    if pd.api.types.is_numeric_dtype(df[col]):
        infs = np.isinf(df[col]).sum()
    else:
        infs = 0
    resultados.append({
        'column': col,
        'null_count': nulos,
        'inf_count': infs
    })

resumen = pd.DataFrame(resultados)
pd.set_option('display.max_rows', None)  # Mostrar todas las filas
resumen
# Out:
#                   column  null_count  inf_count
# 0                 period           0          0
# 1             product_id           0          0
# 2            customer_id           0          0
# 3                     tn           0          0
# 4                 target      525526          0
# 5                periodo           0          0
# 6                   year           0          0
# 7                  month           0          0
# 8          days_in_month           0          0
# 9               semester           0          0
# 10               quarter           0          0
# 11               month_q           0          0
# 12        period_ordinal           0          0
# 13             month_sin           0          0
# 14             month_cos           0          0
# 15           quarter_sin           0          0
# 16           quarter_cos           0          0
# 17    period_ordinal_sin           0          0
# 18    period_ordinal_cos           0          0
# 19             is_summer           0          0
# 20             is_winter           0          0
# 21             pre_march           0          0
# 22           pre_october           0          0
# 23            cat1_FOODS           0          0
# 24               cat1_HC           0          0
# 25               cat1_PC           0          0
# 26              cat1_REF           0          0
# 27               tn_lag1      262805          0
# 28               tn_lag2      525526          0
# 29               tn_lag3      788142          0
# 30               tn_lag4     1050642          0
# 31               tn_lag5     1310741          0
# 32               tn_lag6     1567681          0
# 33               tn_lag7     1819274          0
# 34               tn_lag8     2066722          0
# 35               tn_lag9     2310830          0
# 36              tn_lag10     2546504          0
# 37              tn_lag11     2777480          0
# 38              tn_lag12     3007543          0
# 39              tn_lag13     3237602          0
# 40              tn_lag14     3467330          0
# 41              tn_lag15     3693803          0
# 42              tn_lag16     3916533          0
# 43              tn_lag17     4133416          0
# 44              tn_lag18     4349065          0
# 45              tn_lag19     4562687          0
# 46              tn_lag20     4775408          0
# 47              tn_lag21     4983289          0
# 48              tn_lag22     5186880          0
# 49              tn_lag23     5389158          0
# 50              tn_lag24     5591123          0
# 51              tn_lag25     5792550          0
# 52              tn_lag26     5993927          0
# 53              tn_lag27     6188961          0
# 54              tn_lag28     6379955          0
# 55              tn_lag29     6567729          0
# 56              tn_lag30     6752113          0
# 57              tn_lag31     6932022          0
# 58              tn_lag32     7109220          0
# 59              tn_lag33     7284849          0
# 60              tn_lag34     7458821          0
# 61              tn_lag35     7628113          0
# 62              tn_lag36     7781619          0
# 63              tn_roll2           0          0
# 64           tn_rollstd2      262805          0
# 65           tn_rollmin2           0          0
# 66           tn_rollmax2           0          0
# 67              tn_roll3           0          0
# 68           tn_rollstd3      262805          0
# 69           tn_rollmin3           0          0
# 70           tn_rollmax3           0          0
# 71              tn_roll4           0          0
# 72           tn_rollstd4      262805          0
# 73           tn_rollmin4           0          0
# 74           tn_rollmax4           0          0
# 75              tn_roll5           0          0
# 76           tn_rollstd5      262805          0
# 77           tn_rollmin5           0          0
# 78           tn_rollmax5           0          0
# 79              tn_roll6           0          0
# 80           tn_rollstd6      262805          0
# 81           tn_rollmin6           0          0
# 82           tn_rollmax6           0          0
# 83              tn_roll7           0          0
# 84           tn_rollstd7      262805          0
# 85           tn_rollmin7           0          0
# 86           tn_rollmax7           0          0
# 87              tn_roll8           0          0
# 88           tn_rollstd8      262805          0
# 89           tn_rollmin8           0          0
# 90           tn_rollmax8           0          0
# 91              tn_roll9           0          0
# 92           tn_rollstd9      262805          0
# 93           tn_rollmin9           0          0
# 94           tn_rollmax9           0          0
# 95             tn_roll10           0          0
# 96          tn_rollstd10      262805          0
# 97          tn_rollmin10           0          0
# 98          tn_rollmax10           0          0
# 99             tn_roll11           0          0
# 100         tn_rollstd11      262805          0
# 101         tn_rollmin11           0          0
# 102         tn_rollmax11           0          0
# 103            tn_roll12           0          0
# 104         tn_rollstd12      262805          0
# 105         tn_rollmin12           0          0
# 106         tn_rollmax12           0          0
# 107            tn_roll13           0          0
# 108         tn_rollstd13      262805          0
# 109         tn_rollmin13           0          0
# 110         tn_rollmax13           0          0
# 111            tn_roll14           0          0
# 112         tn_rollstd14      262805          0
# 113         tn_rollmin14           0          0
# 114         tn_rollmax14           0          0
# 115            tn_roll15           0          0
# 116         tn_rollstd15      262805          0
# 117         tn_rollmin15           0          0
# 118         tn_rollmax15           0          0
# 119            tn_roll16           0          0
# 120         tn_rollstd16      262805          0
# 121         tn_rollmin16           0          0
# 122         tn_rollmax16           0          0
# 123            tn_roll17           0          0
# 124         tn_rollstd17      262805          0
# 125         tn_rollmin17           0          0
# 126         tn_rollmax17           0          0
# 127            tn_roll18           0          0
# 128         tn_rollstd18      262805          0
# 129         tn_rollmin18           0          0
# 130         tn_rollmax18           0          0
# 131            tn_roll19           0          0
# 132         tn_rollstd19      262805          0
# 133         tn_rollmin19           0          0
# 134         tn_rollmax19           0          0
# 135            tn_roll20           0          0
# 136         tn_rollstd20      262805          0
# 137         tn_rollmin20           0          0
# 138         tn_rollmax20           0          0
# 139            tn_roll21           0          0
# 140         tn_rollstd21      262805          0
# 141         tn_rollmin21           0          0
# 142         tn_rollmax21           0          0
# 143            tn_roll22           0          0
# 144         tn_rollstd22      262805          0
# 145         tn_rollmin22           0          0
# 146         tn_rollmax22           0          0
# 147            tn_roll23           0          0
# 148         tn_rollstd23      262805          0
# 149         tn_rollmin23           0          0
# 150         tn_rollmax23           0          0
# 151            tn_roll24           0          0
# 152         tn_rollstd24      262805          0
# 153         tn_rollmin24           0          0
# 154         tn_rollmax24           0          0
# 155            tn_roll25           0          0
# 156         tn_rollstd25      262805          0
# 157         tn_rollmin25           0          0
# 158         tn_rollmax25           0          0
# 159            tn_roll26           0          0
# 160         tn_rollstd26      262805          0
# 161         tn_rollmin26           0          0
# 162         tn_rollmax26           0          0
# 163            tn_roll27           0          0
# 164         tn_rollstd27      262805          0
# 165         tn_rollmin27           0          0
# 166         tn_rollmax27           0          0
# 167            tn_roll28           0          0
# 168         tn_rollstd28      262805          0
# 169         tn_rollmin28           0          0
# 170         tn_rollmax28           0          0
# 171            tn_roll29           0          0
# 172         tn_rollstd29      262805          0
# 173         tn_rollmin29           0          0
# 174         tn_rollmax29           0          0
# 175            tn_roll30           0          0
# 176         tn_rollstd30      262805          0
# 177         tn_rollmin30           0          0
# 178         tn_rollmax30           0          0
# 179            tn_roll31           0          0
# 180         tn_rollstd31      262805          0
# 181         tn_rollmin31           0          0
# 182         tn_rollmax31           0          0
# 183            tn_roll32           0          0
# 184         tn_rollstd32      262805          0
# 185         tn_rollmin32           0          0
# 186         tn_rollmax32           0          0
# 187            tn_roll33           0          0
# 188         tn_rollstd33      262805          0
# 189         tn_rollmin33           0          0
# 190         tn_rollmax33           0          0
# 191            tn_roll34           0          0
# 192         tn_rollstd34      262805          0
# 193         tn_rollmin34           0          0
# 194         tn_rollmax34           0          0
# 195            tn_roll35           0          0
# 196         tn_rollstd35      262805          0
# 197         tn_rollmin35           0          0
# 198         tn_rollmax35           0          0
# 199            tn_roll36           0          0
# 200         tn_rollstd36      262805          0
# 201         tn_rollmin36           0          0
# 202         tn_rollmax36           0          0
# 203   tn_is_new_rollmax2           0          0
# 204   tn_is_new_rollmin2           0          0
# 205   tn_is_new_rollmax3           0          0
# 206   tn_is_new_rollmin3           0          0
# 207   tn_is_new_rollmax4           0          0
# 208   tn_is_new_rollmin4           0          0
# 209   tn_is_new_rollmax5           0          0
# 210   tn_is_new_rollmin5           0          0
# 211   tn_is_new_rollmax6           0          0
# 212   tn_is_new_rollmin6           0          0
# 213   tn_is_new_rollmax7           0          0
# 214   tn_is_new_rollmin7           0          0
# 215   tn_is_new_rollmax8           0          0
# 216   tn_is_new_rollmin8           0          0
# 217   tn_is_new_rollmax9           0          0
# 218   tn_is_new_rollmin9           0          0
# 219  tn_is_new_rollmax10           0          0
# 220  tn_is_new_rollmin10           0          0
# 221  tn_is_new_rollmax11           0          0
# 222  tn_is_new_rollmin11           0          0
# 223  tn_is_new_rollmax12           0          0
# 224  tn_is_new_rollmin12           0          0
# 225  tn_is_new_rollmax13           0          0
# 226  tn_is_new_rollmin13           0          0
# 227  tn_is_new_rollmax14           0          0
# 228  tn_is_new_rollmin14           0          0
# 229  tn_is_new_rollmax15           0          0
# 230  tn_is_new_rollmin15           0          0
# 231  tn_is_new_rollmax16           0          0
# 232  tn_is_new_rollmin16           0          0
# 233  tn_is_new_rollmax17           0          0
# 234  tn_is_new_rollmin17           0          0
# 235  tn_is_new_rollmax18           0          0
# 236  tn_is_new_rollmin18           0          0
# 237  tn_is_new_rollmax19           0          0
# 238  tn_is_new_rollmin19           0          0
# 239  tn_is_new_rollmax20           0          0
# 240  tn_is_new_rollmin20           0          0
# 241  tn_is_new_rollmax21           0          0
# 242  tn_is_new_rollmin21           0          0
# 243  tn_is_new_rollmax22           0          0
# 244  tn_is_new_rollmin22           0          0
# 245  tn_is_new_rollmax23           0          0
# 246  tn_is_new_rollmin23           0          0
# 247  tn_is_new_rollmax24           0          0
# 248  tn_is_new_rollmin24           0          0
# 249  tn_is_new_rollmax25           0          0
# 250  tn_is_new_rollmin25           0          0
# 251  tn_is_new_rollmax26           0          0
# 252  tn_is_new_rollmin26           0          0
# 253  tn_is_new_rollmax27           0          0
# 254  tn_is_new_rollmin27           0          0
# 255  tn_is_new_rollmax28           0          0
# 256  tn_is_new_rollmin28           0          0
# 257  tn_is_new_rollmax29           0          0
# 258  tn_is_new_rollmin29           0          0
# 259  tn_is_new_rollmax30           0          0
# 260  tn_is_new_rollmin30           0          0
# 261  tn_is_new_rollmax31           0          0
# 262  tn_is_new_rollmin31           0          0
# 263  tn_is_new_rollmax32           0          0
# 264  tn_is_new_rollmin32           0          0
# 265  tn_is_new_rollmax33           0          0
# 266  tn_is_new_rollmin33           0          0
# 267  tn_is_new_rollmax34           0          0
# 268  tn_is_new_rollmin34           0          0
# 269  tn_is_new_rollmax35           0          0
# 270  tn_is_new_rollmin35           0          0
# 271  tn_is_new_rollmax36           0          0
# 272  tn_is_new_rollmin36           0          0
# 273         tn_div_roll2           0          0
# 274         tn_div_roll3           0          0
# 275         tn_div_roll4           0          0
# 276         tn_div_roll5           0          0
# 277         tn_div_roll6           0          0
# 278         tn_div_roll7           0          0
# 279         tn_div_roll8           0          0
# 280         tn_div_roll9           0          0
# 281        tn_div_roll10           0          0
# 282        tn_div_roll11           0          0
# 283        tn_div_roll12           0          0
# 284        tn_div_roll13           0          0
# 285        tn_div_roll14           0          0
# 286        tn_div_roll15           0          0
# 287        tn_div_roll16           0          0
# 288        tn_div_roll17           0          0
# 289        tn_div_roll18           0          0
# 290        tn_div_roll19           0          0
# 291        tn_div_roll20           0          0
# 292        tn_div_roll21           0          0
# 293        tn_div_roll22           0          0
# 294        tn_div_roll23           0          0
# 295        tn_div_roll24           0          0
# 296        tn_div_roll25           0          0
# 297        tn_div_roll26           0          0
# 298        tn_div_roll27           0          0
# 299        tn_div_roll28           0          0
# 300        tn_div_roll29           0          0
# 301        tn_div_roll30           0          0
# 302        tn_div_roll31           0          0
# 303        tn_div_roll32           0          0
# 304        tn_div_roll33           0          0
# 305        tn_div_roll34           0          0
# 306        tn_div_roll35           0          0
# 307        tn_div_roll36           0          0
# 308            tn_delta1      262805          0
# 309        tn_rel_delta1      262805          0
# 310            tn_delta2      525526          0
# 311        tn_rel_delta2      525526          0
# 312            tn_delta3      788142          0
# 313        tn_rel_delta3      788142          0
# 314            tn_delta4     1050642          0
# 315        tn_rel_delta4     1050642          0
# 316            tn_delta5     1310741          0
# 317        tn_rel_delta5     1310741          0
# 318            tn_delta6     1567681          0
# 319        tn_rel_delta6     1567681          0
# 320            tn_delta7     1819274          0
# 321        tn_rel_delta7     1819274          0
# 322            tn_delta8     2066722          0
# 323        tn_rel_delta8     2066722          0
# 324            tn_delta9     2310830          0
# 325        tn_rel_delta9     2310830          0
# 326           tn_delta10     2546504          0
# 327       tn_rel_delta10     2546504          0
# 328           tn_delta11     2777480          0
# 329       tn_rel_delta11     2777480          0
# 330           tn_delta12     3007543          0
# 331       tn_rel_delta12     3007543          0
# 332            tn_accel1      525526          0
# 333            tn_accel2      788142          0
# 334            tn_accel3     1050642          0
# 335            tn_accel4     1310741          0
# 336            tn_accel5     1567681          0
# 337            tn_accel6     1819274          0
# 338            tn_accel7     2066722          0
# 339            tn_accel8     2310830          0
# 340            tn_accel9     2546504          0
# 341           tn_accel10     2777480          0
# 342           tn_accel11     3007543          0
# 343      tn_trend_slope2      262805          0
# 344      tn_trend_slope3      525526          0
# 345      tn_trend_slope6     1310741          0
# 346      tn_trend_slope9     2066722          0
# 347     tn_trend_slope12     2777480          0
# 348     tn_trend_slope18     4133416          0
# 349     tn_trend_slope24     5389158          0
# 350     tn_trend_slope36     7628113          0
# 351           tn_vs_ma12           0          0
# 352              no_sale           0          0
# 353       no_sale_streak           0          0

# %% [markdown]
# ### Manejo de posibles inf o NaN

# %%
# Convertir todos los infinitos (+Inf y -Inf) en NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# # Ejemplo: ver cuántos infinitos quedan (debería ser cero)
# inf_count_post = {col: np.isinf(df[col]).sum() for col in df.columns if pd.api.types.is_numeric_dtype(df[col])}
# print("Infinitos por columna tras imputar:", inf_count_post)

# %%
df.to_csv('df_with_target_and_features.csv', index=False, sep='\t')
